# %%
from typing import TypeVar


T = TypeVar('T')

def pr(val : T , title:str|None = None , description: str|None = None) : # type: ignore
    if title != None :
        print(f" ---------------------- {title} ---------------------- ")
        if description != None :
            print(f" <-- {description} -->")
    print('type: ' , type(val))
    display(val)
    # return val

# %%
# %matplotlib inline
from __future__ import annotations

from typing import TypeVar, Iterable, Optional, Sequence, Tuple
import numpy as np
import numpy.typing as npt
import pandas as pd

# Matplotlib imports with types
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes

# %% [markdown]
# #  Importing and using Matplotlib

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
# second method 
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
# third method
fig , ax = plt.subplots()
ax.plot(x,y)

# %%
x :np.ndarray = np.array([1,2,3,4])
y :np.ndarray = np.array([10, 20, 25, 30])
fig , ax = plt.subplots(figsize=(6,4))
ax.plot(x , y)
ax.set(title='Simple plot' , xlabel='x Axis' , ylabel='Y Axis')
ax.legend()
ax.grid(True ,alpha=0.3 )
fig.tight_layout()
# plt.savefig('./images/sample-plot.png')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2452\3734135211.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
x : npt.NDArray[np.float64] = np.linspace(0,10 ,100)
y: npt.NDArray[np.float64] = np.sin(x)

fig , ax = plt.subplots(figsize=(8,4))
ax.plot(x , y , color='blue' , label='Sine wave' , linewidth=2 )
ax.set_title('Simple sine wave' , fontsize=14 , fontweight='bold')
ax.set_xlabel('Angle radians')
ax.set_ylabel('sin(x)')
ax.legend(loc='upper right')
ax.grid(True , linestyle='--' , alpha=0.6)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Scatter plot and bar plot
# #### we will focus on
# - line plot
# - scatter plot
# - bar plot
# - histogram plot
# - subplots

# %%
# making figures with numpy arrays
x = np.linspace(0,10 , 100)
fig , ax = plt.subplots()
# create line plot
ax.plot(x , x**2 , label='x = x**2')
ax.set(title='Line plot' , xlabel='x' , ylabel='y')
ax.legend()
plt.show()

# %%
fig , ax = plt.subplots()
# create scatter plots
ax.scatter(x , np.exp(x) , s=15 , alpha=0.7 , label = 'y = e * x')
ax.set(label='Scatter plot' , xlabel = 'x' , ylabel = 'exp(x)')
ax.legend()
plt.show()

# %%
# another scatter plot 
fig , ax = plt.subplots()
ax.scatter(x , x * np.sin(x))

# %%
# make a plot from a dictionary
butter_prices = {
    'Almond Butter' : 10 , 'Peanut Butter' : 8 , 'Cashew Butter' : 12
}
fig , ax = plt.subplots()
ax.bar(butter_prices.keys() , butter_prices.values())
ax.set(title='Butter prices' , ylabel='price ($)' , xlabel='Butter Type');

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4), constrained_layout=True)

ax1.plot(x, x**2, label="x²")
ax1.set(title="Line", xlabel="x", ylabel="y"); ax1.legend()

ax2.scatter(x, np.sin(x), s=15, alpha=0.7, label="sin(x)")
ax2.set(title="Scatter", xlabel="x", ylabel="sin(x)"); ax2.legend()

plt.show()

# %%
prices = {
    'Almond Butter' : 10 , 'Peanut Butter' : 8 , 'Cashew Butter' : 12
}
fig, ax = plt.subplots()
cats, vals = list(prices.keys()), list(prices.values())
bars = ax.bar(cats, vals)

for bar in bars:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
            f"{bar.get_height():.0f}", ha="center", va="bottom")

ax.set(title="Prices", ylabel="$")
fig.tight_layout(); 
plt.show()

# %% [markdown]
# # Histograms and Subplots

# %%
fig , ax = plt.subplots()
ax.barh(prices.keys() , prices.values())
plt.show()

# %%
x = np.random.randn(1000)
fig , ax = plt.subplots()
ax.hist(x);

# %%
fig , ((ax1 , ax2 ) , (ax3 , ax4)) = plt.subplots(nrows=2 , ncols=2 , figsize=(10,5))
ax1.plot(x , x /2)
ax2.scatter(np.random.random(10) , np.random.random(10))
ax3.bar(list(prices.keys()) , list(prices.values()))
ax4.hist(np.random.randn(1000))
# Out:
# (array([ 11.,  56., 119., 220., 219., 219., 106.,  36.,  11.,   3.]),
#  array([-2.82539242, -2.17923246, -1.53307249, -0.88691253, -0.24075257,
#          0.40540739,  1.05156735,  1.69772731,  2.34388727,  2.99004723,
#          3.6362072 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Subplots options 2

# %%
fig , ax = plt.subplots(nrows= 2 , ncols= 2 , figsize=(10,5))
ax[0,0].scatter(x , x ** 2)
ax[0,1].bar(prices.keys() , prices.values())
ax[1,0].scatter(np.random.random(10), np.random.random(10))
ax[1,1].plot(x , x /2)

# %% [markdown]
# # Plotting from pandas Dataframe

# %%
car_sales = pd.read_csv('./data/car-sales.csv')
pr(car_sales)
# Out:
# type:  <class 'pandas.core.frame.DataFrame'>
#      Make  Color  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
plt.style.use('ggplot')

# %%
ts = pd.Series(np.random.randn(1000) , index = pd.date_range('1/1/2020' , periods=1000))
ts = ts.cumsum()
ax =  ts.plot(figsize=(9,4) , title="Cumulative Random Series (Pandas → Matplotlib)")
ax.set_xlabel('Date')
ax.set_ylabel('value')
plt.show()

# %%
make_counts:pd.Series = car_sales['Make'].value_counts()
pr(make_counts)
ax = make_counts.plot.bar(
    figsize= (9,4),
    title="Car make count",
    rot=0 ,
    color="#4C72B0",
    edgecolor="black",
)
ax.set_xlabel('Make')
ax.set_ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# type:  <class 'pandas.core.series.Series'>
# Make
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: count, dtype: int64

# %% [markdown]
# # Plotting From Pandas DataFrames 2

# %%
sales = car_sales.copy()
# remove the `$` , `,` , `.` signs from the price column
sales['Price'] = sales['Price'].str.replace(r'[$,.]' , '' , regex=True)
# remove the two zeros from the right.
sales['Price'] = sales['Price'].str[:-1].astype('int')
# add Sale Date column
sales['Sales Date'] = pd.date_range('1/1/2020' , periods=len(sales))
# let's add a total column
sales['Total'] = sales['Price'].cumsum()
pr(sales)
# Out:
# type:  <class 'pandas.core.frame.DataFrame'>
#      Make  Color  Odometer (KM)  Doors   Price Sales Date   Total
# 0  Toyota  White         150043      4   40000 2020-01-01   40000
# 1   Honda    Red          87899      4   50000 2020-01-02   90000
# 2  Toyota   Blue          32549      3   70000 2020-01-03  160000
# 3     BMW  Black          11179      5  220000 2020-01-04  380000
# 4  Nissan  White         213095      4   35000 2020-01-05  415000
# 5  Toyota  Green          99213      4   45000 2020-01-06  460000
# 6   Honda   Blue          45698      4   75000 2020-01-07  535000
# 7   Honda   Blue          54738      4   70000 2020-01-08  605000
# 8  Toyota  White          60000      4   62500 2020-01-09  667500
# 9  Nissan  White          31600      4   97000 2020-01-10  764500

# %%
# let's plot the total sales
ax = sales.plot(x='Sales Date' , y='Total')
ax.set_xlabel('Sale Date')
ax.set_ylabel('Total Sales ($)')
plt.tight_layout()
plt.show()

# %%
sales.plot(x='Odometer (KM)' , y='Price' , kind='scatter')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# # Plotting from Pandas DataFrames 3

# %%
# let's create a bar graph.
x = np. random.rand(10,4)
# turn x to a dataframe
df = pd.DataFrame(x, columns=list('ABCD'))
df.plot.bar()
# Out:
# <Axes: >

# %%
sales.plot.bar(x = 'Make' , y='Price')
# Out:
# <Axes: xlabel='Make'>

# %%
sales['Price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Plotting from Pandas DataFrames 4

# %%
heart_disease = pd.read_csv('./data/heart-disease.csv')
pr(heart_disease.head())
# Out:
# type:  <class 'pandas.core.frame.DataFrame'>
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a histogram to see the distribution for the age column
ax = heart_disease['age'].plot.hist(bins=15)
ax.set_xlabel('percentiles')
ax.set_ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
heart_disease.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Plotting from Pandas DataFrames 5

# %%
# in this lesson we will look on how to use oo method with matplotlib
over_50 = heart_disease[heart_disease['age'] > 50]
pr(over_50.head())
pr(len(over_50) , 'count of over 50 patients')
# Out:
# type:  <class 'pandas.core.frame.DataFrame'>
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
#  ---------------------- count of over 50 patients ----------------------
# type:  <class 'int'>
# 208

# %%
# pyplot method - plotting directly from a data frame.
ax = over_50.plot.scatter(x='age' , y='chol' )
ax.set_xlabel('age')
ax.set_ylabel('cholesterol')
# Out:
# Text(0, 0.5, 'cholesterol')

# %%
## using oop method with plot
fig ,ax = plt.subplots(figsize=(10,5))
over_50.plot(kind='scatter' , x='age' , y='chol', ax=ax)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %% [markdown]
# # Plotting from Pandas DataFrames 6

# %%
# OO method from scratch.
fig ,ax = plt.subplots(figsize=(10,5))
scatter = ax.scatter(x=over_50['age'] , y=over_50['chol'] , c=over_50['target'])
ax.set(
    title='Heart Disease and cholesterol levels', 
    xlabel='age' ,
    ylabel='cholesterol' ,
    )
ax.legend(*scatter.legend_elements() , title='target')
# add a horizontal line at the average of chol
ax.axhline(np.average(over_50['chol']) , linestyle='--')

# %% [markdown]
# # Plotting from Pandas DataFrames 7

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol and thlach. the two subplots will share the age on the x-axis
fig , (ax0 , ax1) = plt.subplots(nrows=2 , ncols=1 , figsize=(10,10) , sharex=True)
scatter0 = ax0.scatter(x=over_50['age'] , y=over_50['chol'] , c=over_50['target'])
ax0.set(  ylabel='cholesterol' , title="Heart disease and cholesterol levels")
ax0.legend(*scatter0.legend_elements() , title='Target')
ax0.axhline(y=over_50['chol'].mean() , linestyle='--')
scatter1 = ax1.scatter(x=over_50['age'] , y=over_50['thalach'] , c=over_50['target'])
ax1.set(xlabel='age' , ylabel='max heart rate' , title="Heart disease and max heart rate")
ax1.legend(*scatter1.legend_elements() , title='Target')
ax1.axhline(y=over_50['thalach'].mean() , linestyle='--')
fig.suptitle('Heart Disease Analysis' , fontsize=16 , fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')
